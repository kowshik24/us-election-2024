# %% [markdown]
# # Load dataset

# %%
import pandas as pd
df = pd.read_csv("/content/may_july_chunk_1.csv")

# %%
df.head()
# Out:
#                     id                                               text  \
# 0  1801041792923578484  @lukepbeasley I cant imagine anyone actually f...
# 1  1801041792630227173  Voters can also sway me away from voting  for ...
# 2  1801041792592224521  @PoodleHead57 @BobOnderMO Can you name that am...
# 3  1801041791463866688  @Morning_Joe @JoeNBC The fact remains that Joe...
# 4  1801041790952231228  @BidenHQ That's funny you're obviously trying ...
#
#                                                  url       epoch media  \
# 0  https://twitter.com/orgneyezedchaos/status/180...  1718236799    []
# 1  https://twitter.com/Brandon62294232/status/180...  1718236799    []
# 2  https://twitter.com/JohnRMBR911/status/1801041...  1718236799    []
# 3  https://twitter.com/andy_leq/status/1801041791...  1718236799    []
# 4  https://twitter.com/Ranchhandlb7/status/180104...  1718236799    []
#
#    retweetedTweet  retweetedTweetID  retweetedUserID               id_str  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'text', 'url', 'epoch', 'media', 'retweetedTweet',
#        'retweetedTweetID', 'retweetedUserID', 'id_str', 'lang', 'rawContent',
#        'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'conversationIdStr', 'hashtags', 'mentionedUsers',
#        'links', 'viewCount', 'quotedTweet', 'in_reply_to_screen_name',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id_str', 'location',
#        'cash_app_handle', 'user', 'date', '_type'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# id                                                         1801041792923578484
# text                         @lukepbeasley I cant imagine anyone actually f...
# url                          https://twitter.com/orgneyezedchaos/status/180...
# epoch                                                               1718236799
# media                                                                       []
# retweetedTweet                                                           False
# retweetedTweetID                                                           NaN
# retweetedUserID                                                            NaN
# id_str                                                     1801041792923578484
# lang                                                                        en
# rawContent                   @lukepbeasley I cant imagine anyone actually f...
# replyCount                                                                   0
# ...

# %%
df.shape
# Out:
# (50000, 30)

# %%
# Take the first 1000 rows

sample_df = df.head(1000)

# %%
sample_df.shape
# Out:
# (1000, 30)

# %%
sample_df.iloc[0].id
# Out:
# 1801041792923578484

# %%
sample_df.iloc[0].text
# Out:
# '@lukepbeasley I cant imagine anyone actually feels this way. As much as you hate Donald trump, you don’t believe this. Brainwashed, complicit (black mail or money), or just have no clue whats going in and just want to fit in somewhere. There are no other options'

# %%
sample_df.iloc[0].url
# Out:
# 'https://twitter.com/orgneyezedchaos/status/1801041792923578484'

# %%
sample_df.iloc[0].epoch
# Out:
# 1718236799

# %%
sample_df.iloc[0].media
# Out:
# '[]'

# %%
sample_df.iloc[0].rawContent
# Out:
# '@lukepbeasley I cant imagine anyone actually feels this way. As much as you hate Donald trump, you don’t believe this. Brainwashed, complicit (black mail or money), or just have no clue whats going in and just want to fit in somewhere. There are no other options'

# %%
sample_df.iloc[0].mentionedUsers
# Out:
# "[{'id_str': '1483596463221264387', 'name': 'Luke Beasley', 'screen_name': 'lukepbeasley', 'indices': [0, 13]}]"

# %%
sample_df.iloc[0].viewCount
# Out:
# "{'count': '10', 'state': 'EnabledWithCount'}"

# %%
sample_df.iloc[0].user
# Out:
# "{'id': 942869257108455424, 'id_str': '942869257108455424', 'url': 'https://twitter.com/B. G. Dalena', 'username': 'B. G. Dalena', 'rawDescription': 'Therapist. Philosophy, Epistemology, Politics, Neuroscience, Golf, Art, Sports, and a relentless pursuit of the truth.', 'created': datetime.datetime(2017, 12, 18, 21, 28, 43, tzinfo=datetime.timezone.utc), 'followersCount': 152, 'friendsCount': 246, 'statusesCount': 390, 'favouritesCount': 19, 'listedCount': 0, 'mediaCount': 1, 'location': 'San Diego, CA', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1613647617594130432/h3jM9GzR_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}"

# %%
sample_df['text'].dropna()
# Out:
# 0      @lukepbeasley I cant imagine anyone actually f...
# 1      Voters can also sway me away from voting  for ...
# 2      @PoodleHead57 @BobOnderMO Can you name that am...
# 3      @Morning_Joe @JoeNBC The fact remains that Joe...
# 4      @BidenHQ That's funny you're obviously trying ...
#                              ...
# 995    @corrcomm @paladine @AP remind us how you feel...
# 996    The only way to do that is by having a Democra...
# 997    I rarely meet T voters who admit was mistake/ ...
# 998    @skangdaddyflexx @AdamGoldberg28 You really th...
# 999                                        😂😂😂😂😂🇺🇸🇺🇸🇺🇸🇺🇸
# Name: text, Length: 1000, dtype: object

# %%
# !pip install bertopic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 56.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.9 MB/s eta 0:00:00
# ...

# %%
df = sample_df

# %%
from bertopic import BERTopic
import pandas as pd



texts = df['text'].dropna().tolist()


model = BERTopic()
topics, probs = model.fit_transform(texts)


topic_info = model.get_topic_info()


print("Top Topics:")
print(topic_info.head())

print("\nKeywords for Topic 0:")
print(model.get_topic(0))


df['topic'] = topics


topic_info.to_csv("topics_info.csv", index=False)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Top Topics:
#    Topic  Count                                          Name  \
# 0      0    984                            0_the_to_biden_and
# 1      1     16  1_wg8ca9oqes24103_nepolabomaga_maga_uniparty
#
#                                       Representation  \
# ...

# %%
df.head()
# Out:
#                     id                                               text  \
# 0  1801041792923578484  @lukepbeasley I cant imagine anyone actually f...
# 1  1801041792630227173  Voters can also sway me away from voting  for ...
# 2  1801041792592224521  @PoodleHead57 @BobOnderMO Can you name that am...
# 3  1801041791463866688  @Morning_Joe @JoeNBC The fact remains that Joe...
# 4  1801041790952231228  @BidenHQ That's funny you're obviously trying ...
#
#                                                  url       epoch media  \
# 0  https://twitter.com/orgneyezedchaos/status/180...  1718236799    []
# 1  https://twitter.com/Brandon62294232/status/180...  1718236799    []
# 2  https://twitter.com/JohnRMBR911/status/1801041...  1718236799    []
# 3  https://twitter.com/andy_leq/status/1801041791...  1718236799    []
# 4  https://twitter.com/Ranchhandlb7/status/180104...  1718236799    []
#
#    retweetedTweet  retweetedTweetID  retweetedUserID               id_str  \
# ...

# %%
topics_df = pd.read_csv("/content/topics_info.csv")

# %%
topic_info.head()
# Out:
#    Topic  Count                                          Name  \
# 0      0    984                            0_the_to_biden_and
# 1      1     16  1_wg8ca9oqes24103_nepolabomaga_maga_uniparty
#
#                                       Representation  \
# 0  [the, to, biden, and, is, of, you, in, for, that]
# 1  [wg8ca9oqes24103, nepolabomaga, maga, uniparty...
#
#                                  Representative_Docs
# 0  [@RpsAgainstTrump @AdamKinzinger CNN? Corporat...
# 1  [MAGA🔥, @wg8cA9OqES24103 あ！わかった😆\n\n自分のことをそんなふ...

# %%
topic_info.shape
# Out:
# (2, 5)

# %%
topic_info.columns
# Out:
# Index(['Topic', 'Count', 'Name', 'Representation', 'Representative_Docs'], dtype='object')

# %%
topic_info.iloc[0].Name
# Out:
# '0_the_to_biden_and'

# %%
topic_info.iloc[0].Representation
# Out:
# ['the', 'to', 'biden', 'and', 'is', 'of', 'you', 'in', 'for', 'that']

# %%
topic_info.iloc[1].Representation
# Out:
# ['wg8ca9oqes24103',
#  'nepolabomaga',
#  'maga',
#  'uniparty',
#  'correct',
#  'like',
#  'its',
#  'and',
#  'the',
#  '']

# %%
topic_info.iloc[0].Representative_Docs
# Out:
# ['@RpsAgainstTrump @AdamKinzinger CNN? Corporate-Intel Media? Joe Biden? Everyone on the left side of the Political Ledger? You are not Republicans and need to be excised from the GOP. The Goldwater Institute is taking a good hard look at you guys and others as a matter of legal recourse.',
#  '@youknowbetter23 That was the case before the court. Do you know how courts work? It is factual they did as well. It is factual that catch and kill schemes are also a form of the same thing. There is now a new precedent about story suppression and that is a good thing. It wasn’t Biden alone.',
#  '@erinnthered I saw that as she was trying to remind us of the heartache the Biden family has gone through, in the president losing his first wife. But I can see how you would hear it that way… I just think there’s a lot worse out there right now in the media.']

# %%
topic_info.iloc[1].Representative_Docs
# Out:
# ['MAGA🔥',
#  '@wg8cA9OqES24103 あ！わかった😆\n\n自分のことをそんなふうに言っちゃダメ😆😆',
#  'Correct. It’s the Uni-Party and MAGA😜']
